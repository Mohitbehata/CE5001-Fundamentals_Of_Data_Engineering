# %%
# pip is python install package commandline utility
# ! mark is need to run commandline tools
# !pip install faker
import faker
import sys
import csv

# %% [markdown]
# This code installs the "faker" library using pip, imports the "faker" module, "sys" module, and "csv" module, and does not perform any more actions beyond making these resources available for use in our script below.

# %% [markdown]
#  We have to create a CSV file with randomly generated data and save it as 'sample_data.csv'.

# %%
from faker import Faker
import csv

# Select the locale for fake data
fake = Faker('en_US')

# Open a CSV file to write (UTF-8 encoding to support emojis)
with open('sample_data.csv', mode='w', encoding='utf-8') as sample_data:
    writer = csv.writer(sample_data)

    # Write the header row
    writer.writerow(['Name', 'State', 'Plate', 'SSN', 'Occupation', 'Emoji'])

    # Generate and write 1000 rows of random data
    for _ in range(1000):
        writer.writerow([fake.name(), fake.state_abbr(), fake.license_plate(), fake.ssn(), fake.job(), fake.emoji()])

# %% [markdown]
# - Create a Faker object named "fake" and specify the locale as 'en_US' to generate data in English with US convention.
# - Open a CSV file named "sample_data.csv" for writing, using UTF-8 encoding to support emojis.
# - Create a CSV writer object called "writer" to write data to the CSV file.
# - Write the header row to the CSV file, specifying the column names. using **fake.__()** (1000 rows of randomly generated fake data, with columns for name, state abbreviation, license plate number, SSN, occupation, and emoji.)

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data.csv')
df.head()
# Out:
#             Name State     Plate          SSN               Occupation  Emoji
# 0     Linda Reed    WV  UF4 5540  864-16-5629    Adult guidance worker     🇱🇾
# 1   Caitlin Hale    NV   5981 FO  636-48-2013    Accounting technician      👩
# 2  Zachary Davis    CO   8989 PB  619-47-5807  Presenter, broadcasting  🏊🏻‍♂️
# 3   Cameron Dyer    PW     1I758  108-78-1177     Engineer, automotive    👨‍🌾
# 4    Mark Walker    GA   Y66 7AR  642-26-8708   Occupational therapist     🖊️

# %% [markdown]
# - Using pandas to handle the csv file as a dataframe for further procedure.

# %%
df.drop(df[df['State'] != 'MO'].index, inplace = True)
df.head()
# Out:
#                   Name State     Plate          SSN  \
# 11    Spencer Thornton    MO   750-HBQ  036-50-9995
# 75   Samantha Thornton    MO   232-FMK  255-57-9785
# 138    Sheila Chandler    MO   UYN-334  203-27-4580
# 227         Tyler Hood    MO  7O 3299E  747-16-7892
# 241        Ashley Cruz    MO   646 0FI  166-24-8982
#
#                                 Occupation    Emoji
# 11   English as a foreign language teacher       👰🏿
# 75                            Statistician        🐞
# 138                           Set designer  👩‍👩‍👧‍👦
# 227             Regulatory affairs officer       🏂🏿
# 241                              Solicitor        🪒

# %% [markdown]
# - From the dataframe we have we are removing all such rows where state is not MO.

# %%
def formatting_ssn(x):
    return ''.join(x.split('-'))

# %% [markdown]
# - We are creating a function to formatting_ssn as per the task given.
# - We are removing all '-' and combining the ssn into single number from "xxx-xxx-xxxx"to "xxxxxxxxx".

# %%
df['SSN'] = df['SSN'].map(formatting_ssn)
df.head()
# Out:
#                   Name State     Plate        SSN  \
# 11    Spencer Thornton    MO   750-HBQ  036509995
# 75   Samantha Thornton    MO   232-FMK  255579785
# 138    Sheila Chandler    MO   UYN-334  203274580
# 227         Tyler Hood    MO  7O 3299E  747167892
# 241        Ashley Cruz    MO   646 0FI  166248982
#
#                                 Occupation    Emoji
# 11   English as a foreign language teacher       👰🏿
# 75                            Statistician        🐞
# 138                           Set designer  👩‍👩‍👧‍👦
# 227             Regulatory affairs officer       🏂🏿
# 241                              Solicitor        🪒

# %% [markdown]
# - This line applies the format_ssn function to every value in the 'SSN' column of the DataFrame.
# - The .map() method is used to apply the function to each element of the specified column.
# - The result of applying the function is assigned back to the 'SSN' column in the DataFrame, effectively replacing the original SSNs with the formatted versions.

# %%
df.to_csv('output_data.tsv', sep="\t")

# %%
df.to_json('output_data.json')

# %% [markdown]
# **Conclusion:**
#
# Data Generation:
#
# - Random fake data is generated using the "Faker" library.
# - This data is written to a CSV file named "sample_data.csv."
#
# Data Loading:
#
# - The data from "sample_data.csv" is loaded into a Pandas DataFrame called "df."
#
# Data Filtering:
#
# - Rows in the DataFrame where the 'State' column is not 'MO' (Missouri) are removed, effectively filtering the data.
#
# Data Transformation:
#
# - The 'SSN' column in the DataFrame is formatted by removing hyphens from Social Security Numbers.
#
# Data Export:
#
# - The filtered and transformed DataFrame is exported to two different file formats:
# A tab-separated values (TSV) file named "output_data.tsv."
# - A JSON file named "output_data.json."
